# %%
# Out:
# c:\Users\Ahmed\.conda\envs\NN\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from final_project import *

signals1 = load_subjects()
signals2 = load_subjects()
signals3 = load_subjects()

# %%
non_fid_features_b, non_fid_features_values_b = non_fiducial_features_bonus_preprocessing(signals1)
# Out:
# d:\Nourhan\8th semester\HCI\ECG-Based-Authentication-Interface\04.GUI\final_project.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i] = non_fid[i]
# d:\Nourhan\8th semester\HCI\ECG-Based-Authentication-Interface\04.GUI\final_project.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i] = non_fid[i]
# ...

# %%
type(non_fid_features_values_b)
# Out:
# list

# %%
len(non_fid_features_values_b)
# Out:
# 10

# %%
df1 = pd.DataFrame(non_fid_features_values_b[0])
df2 = pd.DataFrame(non_fid_features_values_b[1])
df3 = pd.DataFrame(non_fid_features_values_b[2])
df4 = pd.DataFrame(non_fid_features_values_b[3])
df5 = pd.DataFrame(non_fid_features_values_b[4])
df6 = pd.DataFrame(non_fid_features_values_b[5])
df7 = pd.DataFrame(non_fid_features_values_b[6])

# %%
Data = pd.concat([df1, df2, df3, df4, df5, df6, df7], ignore_index=True)

# %%
Data.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  5.395555  5.409450  5.406529  5.354149  5.683511  4.421094  0.101043
# 1  5.424897  5.442171  5.437638  5.379841  5.743223  4.355831  0.105143
# 2  5.832266  5.849857  5.845597  5.784263  6.169253  4.697847  0.080650
# 3  6.023121  6.040406  6.036284  5.973749  6.367676  4.860820  0.098701
# 4  5.666614  5.679994  5.677228  5.622830  5.967205  4.645027  0.094460
#
#          7         8         9   ...        31        32        33        34  \
# 0 -0.757927 -0.787183 -0.648457  ... -0.247885 -0.270287 -0.303115 -0.313562
# 1 -0.691530 -0.732095 -0.619256  ... -0.295524 -0.318051 -0.323567 -0.340800
# 2 -0.753078 -0.734359 -0.592052  ... -0.412551 -0.433928 -0.471581 -0.488298
# 3 -0.782645 -0.761574 -0.665161  ... -0.441157 -0.473204 -0.482807 -0.494610
# 4 -0.759591 -0.766009 -0.671178  ... -0.359466 -0.405824 -0.436926 -0.462700
#
#          35        36        37        38        39   40
# ...

# %%
Data.shape
# Out:
# (854, 41)

# %%
X_train = Data.drop(40, axis=1)
y = Data[40]

# %%
random_forest_classifier(X_train, y, "random_forest_classifier_nonFidBonus.pkl")

# %%
# Out:
# 115200 115200 115200
# 115200 115200 115200
# 115200 115200 115200
# 115200 115200 115200
# 115200 115200 115200
# 115200 115200 115200
# 120012 120012 120012
# 120012 120012 120012
# 120012 120012 120012
# 120012 120012 120012

# %%
non_fid_features, non_fid_features_values = non_fiducial_features(signals3)

# %%
non_fid_features_values = np.array(non_fid_features_values)
non_fid_features_values = non_fid_features_values.reshape(10,81)

# %%
non_fid_features_values.shape
# Out:
# (10, 81)

# %%
import pandas as pd
df_fid = pd.DataFrame(non_fid_features_values)
df_fid
# Out:
#           0          1          2          3          4          5   \
# 0  15.961305 -16.147358  49.957671   7.223245  13.113433   8.156769
# 1  11.679354 -12.720458  43.093981  43.208929 -16.348405  18.907453
# 2   7.321660  -7.503761  32.308658  29.544112  -3.937882  93.228254
# 3  17.593252 -17.610454  49.227540  -0.622000  23.153253   1.506058
# 4   7.159621  -5.964107  19.344678   9.922707   2.918072   7.841262
# 5  19.323972 -19.942999  42.031949  49.209136  -7.733786   8.484694
# 6  -5.682426   8.207733  26.497108  11.716179  15.263394  19.498810
# 7   1.462225   0.411287   3.662835  13.801019  -0.708683  11.642220
# 8  -2.223655   3.901904   2.868681  11.349040  -6.034517  22.070113
# 9  23.483496 -24.200254  71.812292  -3.647732  28.712345  -7.288428
#
#           6          7           8           9   ...        71        72  \
# 0  36.602683  86.711089   35.503631  130.251751  ... -0.041910 -0.115546
# ...

# %%
x_train = non_fid_features_values[:7,:-1]
y_train = non_fid_features_values[:7,-1]

# %%
y_train
# Out:
# array([1., 2., 3., 4., 5., 6., 7.])

# %%
random_forest_classifier(x_train, y_train, "random_forest_classifier_nonFid.pkl")

# %%
fid_features, fid_features_values = Fiducial_Features(signals2)

# %%
df1 = pd.DataFrame(fid_features_values[0])
df2 = pd.DataFrame(fid_features_values[1])
df3 = pd.DataFrame(fid_features_values[2])
df4 = pd.DataFrame(fid_features_values[3])
df5 = pd.DataFrame(fid_features_values[4])
df6 = pd.DataFrame(fid_features_values[5])
df7 = pd.DataFrame(fid_features_values[6])
df8 = pd.DataFrame(fid_features_values[7])
df9 = pd.DataFrame(fid_features_values[8])
df10 = pd.DataFrame(fid_features_values[9])

# %%
df4
# Out:
#            0         1         2         3         4         5         6   \
# 0       871.0 -0.162201     926.0 -0.083372     898.0  0.693483     856.0
# 1      1884.0 -0.156252    1938.0 -0.070448    1911.0  0.659926    1869.0
# 2      2924.0 -0.164025    2979.0 -0.066582    2951.0  0.667611    2909.0
# 3      3965.0 -0.164350    4020.0 -0.072907    3992.0  0.676129    3950.0
# 4      4956.0 -0.167549    5011.0 -0.088315    4983.0  0.703564    4941.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 117  115654.0 -0.172956  115709.0 -0.073036  115682.0  0.710942  115640.0
# 118  116624.0 -0.155965  116679.0 -0.072639  116652.0  0.670440  116610.0
# 119  117626.0 -0.159008  117681.0 -0.075365  117654.0  0.666854  117612.0
# 120  118668.0 -0.166475  118722.0 -0.076435  118695.0  0.679385  118653.0
# 121  119676.0 -0.171716  119730.0 -0.082576  119703.0  0.701545  119661.0
#
#            7         8         9   ...        13        14        15  \
# ...

# %%
Data = pd.concat([df1, df2, df3, df4, df5, df6, df7], ignore_index=True)

# %%
Data.head()
# Out:
#        0         1       2         3       4         5       6         7   \
# 0   762.0 -0.218743   882.0 -0.139171   799.0  1.011308   749.0 -0.169465
# 1  1672.0 -0.205465  1785.0 -0.140809  1709.0  0.966185  1659.0 -0.158040
# 2  2585.0 -0.204541  2694.0 -0.127283  2623.0  0.975988  2572.0 -0.163129
# 3  3444.0 -0.221023  3556.0 -0.141537  3481.0  1.046277  3430.0 -0.163625
# 4  4289.0 -0.227211  4399.0 -0.145013  4326.0  1.080314  4275.0 -0.169533
#
#        8         9   ...      13        14        15      16        17  \
# 0   851.0 -0.109030  ...   704.0 -0.077050 -0.092504  1065.0  0.237156
# 1  1762.0 -0.111132  ...  1614.0 -0.084467 -0.085714  1976.0  0.240790
# 2  2675.0 -0.097540  ...  2526.0 -0.073780 -0.082077  2888.0  0.225152
# 3  3533.0 -0.113058  ...  3386.0 -0.083264 -0.104196  3744.0  0.225443
# 4  4378.0 -0.114767  ...  4230.0 -0.084257 -0.096518  4590.0  0.234956
#
#        18      19        20        21   22
# 0   983.0  1129.0 -0.047551 -0.029896  1.0
# ...

# %%
X_train = Data.drop(22, axis=1)
y = Data[22]

# %%
random_forest_classifier(X_train, y, "random_forest_classifier_Fid.pkl")

# %%
import pickle
fid_model = pickle.load(open('random_forest_classifier_Fid.pkl', 'rb'))

# %%
X_train = df10.drop(22, axis=1)
y = df10[22]

p = fid_model.predict_proba(X_train)

# %%
threshold_percentage = 0.8
flag = 0
for i in range(0, len(p)):
    for subject_id, percentage in enumerate(p[i]):

        if percentage >= threshold_percentage:
            print(
                f"Identified as subject {subject_id+1} with {percentage*100}% certainty.")
            flag = 1
    if flag == 1:
        break

if flag == 0:
    print("subject is undefind")
# Out:
# subject is undefind

# %%
from final_project import *

signals1 = load_subjects()
signals2 = load_subjects()
signals3 = load_subjects()
# Out:
# c:\Users\Ahmed\.conda\envs\NN\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
selected_signal = signals1[1]
selected_signal
# Out:
# (array([0.00877724, 0.00944403, 0.01009738, ..., 0.00045572, 0.00042509,
#         0.00040158]),
#  array([7.94471726e-05, 8.11516779e-05, 8.20431476e-05, ...,
#         6.02733217e-05, 5.40837415e-05, 4.75424900e-05]),
#  array([7.94471726e-05, 8.11516779e-05, 8.20431476e-05, ...,
#         6.02733217e-05, 5.40837415e-05, 4.75424900e-05]))

# %%
from feature_extraction import *

# %%
samp_start = 0
samp_end = 2000

# %%
res = points_for_plot(selected_signal,start=samp_start,end=samp_end)

# %%
res['time']
# Out:
# 0.003

# %%
import matplotlib.pyplot as plt
import numpy as np

fs = 1000
time = len(res['denoised_signal'])/fs
ts = np.arange(0,time, 1.0 / fs)
plt.figure(figsize=(10,7))
plt.plot(ts, res['denoised_signal'],alpha=0.6, lw=1, label="Raw signal")
plt.scatter(res['qx']/fs, res['qy'], alpha=0.5, color='red', label="Q point")
plt.scatter(res['sx']/fs, res['sy'], alpha=0.5, color='green', label="S point")
plt.scatter(res['Rx']/fs, res['Ry'], alpha=0.5, color='blue', label="R point")
plt.scatter(res['qrs_on_x']/fs, res['qrs_on_y'], alpha=0.5, color='black', label="QRS onset")
plt.scatter(res['qrs_off_x']/fs, res['qrs_off_y'], alpha=0.5, color='yellow', label="QRS offset")
plt.scatter(res['Px']/fs, res['Py'], alpha=0.5, color='orange', label="P point")
plt.scatter(res['p_on_x']/fs, res['p_on_y'], alpha=0.5, color='pink', label="P onset")
plt.scatter(res['p_off_x']/fs, res['p_off_y'], alpha=0.5, color='cyan', label="P offset")
plt.scatter(res['Tx']/fs, res['Ty'], alpha=0.5, color='purple', label="T point")
plt.scatter(res['t_on_x']/fs, res['t_on_y'], alpha=0.5, color='brown', label="T onset")
plt.scatter(res['t_off_x']/fs, res['t_off_y'], alpha=0.5, color='gray', label="T offset")
plt.legend(loc='upper right')
plt.show()

# %%
def create_array(start, end, diff):
    array = []
    current = start
    while current <= end:
        array.append(current)
        current += diff
    return array

start = 0  # Starting number
end = 10/1000   # Ending number
diff = 1/1000  # Difference between consecutive numbers

result = create_array(start, end, diff)
print(result)
# Out:
# [0, 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009000000000000001]
